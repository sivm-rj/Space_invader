# %% [markdown]
# <a href="https://colab.research.google.com/github/sivm-rj/Space_invader/blob/main/Space_invader.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install git+https://github.com/DLR-RM/rl-baselines3-zoo
# Out:
# Collecting git+https://github.com/DLR-RM/rl-baselines3-zoo
#   Cloning https://github.com/DLR-RM/rl-baselines3-zoo to /tmp/pip-req-build-30f9awse
#   Running command git clone --filter=blob:none --quiet https://github.com/DLR-RM/rl-baselines3-zoo /tmp/pip-req-build-30f9awse
#   Resolved https://github.com/DLR-RM/rl-baselines3-zoo to commit cd701a094ac5120f1795c747fd4c490aa79f94e6
#   Running command git submodule update --init --recursive -q
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting sb3_contrib<3.0,>=2.7.0a0 (from rl_zoo3==2.7.0a0)
#   Downloading sb3_contrib-2.7.0a0-py3-none-any.whl.metadata (4.1 kB)
# Collecting gymnasium<1.2.0,>=0.29.1 (from rl_zoo3==2.7.0a0)
#   Downloading gymnasium-1.1.1-py3-none-any.whl.metadata (9.4 kB)
# Collecting huggingface_sb3<4.0,>=3.0 (from rl_zoo3==2.7.0a0)
#   Downloading huggingface_sb3-3.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from rl_zoo3==2.7.0a0) (4.67.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from rl_zoo3==2.7.0a0) (13.9.4)
# Collecting optuna>=3.0 (from rl_zoo3==2.7.0a0)
#   Downloading optuna-4.4.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from rl_zoo3==2.7.0a0) (6.0.2)
# Collecting pytablewriter~=1.2 (from rl_zoo3==2.7.0a0)
#   Downloading pytablewriter-1.2.1-py3-none-any.whl.metadata (38 kB)
# Collecting shimmy~=2.0 (from rl_zoo3==2.7.0a0)
#   Downloading Shimmy-2.0.0-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium<1.2.0,>=0.29.1->rl_zoo3==2.7.0a0) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium<1.2.0,>=0.29.1->rl_zoo3==2.7.0a0) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium<1.2.0,>=0.29.1->rl_zoo3==2.7.0a0) (4.14.1)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium<1.2.0,>=0.29.1->rl_zoo3==2.7.0a0) (0.0.4)
# Requirement already satisfied: huggingface-hub~=0.8 in /usr/local/lib/python3.11/dist-packages (from huggingface_sb3<4.0,>=3.0->rl_zoo3==2.7.0a0) (0.33.4)
# Requirement already satisfied: wasabi in /usr/local/lib/python3.11/dist-packages (from huggingface_sb3<4.0,>=3.0->rl_zoo3==2.7.0a0) (1.1.3)
# Collecting alembic>=1.5.0 (from optuna>=3.0->rl_zoo3==2.7.0a0)
#   Downloading alembic-1.16.4-py3-none-any.whl.metadata (7.3 kB)
# Collecting colorlog (from optuna>=3.0->rl_zoo3==2.7.0a0)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from optuna>=3.0->rl_zoo3==2.7.0a0) (25.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna>=3.0->rl_zoo3==2.7.0a0) (2.0.41)
# Requirement already satisfied: setuptools>=38.3.0 in /usr/local/lib/python3.11/dist-packages (from pytablewriter~=1.2->rl_zoo3==2.7.0a0) (75.2.0)
# Collecting DataProperty<2,>=1.1.0 (from pytablewriter~=1.2->rl_zoo3==2.7.0a0)
#   Downloading DataProperty-1.1.0-py3-none-any.whl.metadata (11 kB)
# Collecting mbstrdecoder<2,>=1.0.0 (from pytablewriter~=1.2->rl_zoo3==2.7.0a0)
#   Downloading mbstrdecoder-1.1.4-py3-none-any.whl.metadata (4.3 kB)
# Collecting pathvalidate<4,>=2.3.0 (from pytablewriter~=1.2->rl_zoo3==2.7.0a0)
#   Downloading pathvalidate-3.3.1-py3-none-any.whl.metadata (12 kB)
# Collecting tabledata<2,>=1.3.1 (from pytablewriter~=1.2->rl_zoo3==2.7.0a0)
#   Downloading tabledata-1.3.4-py3-none-any.whl.metadata (3.7 kB)
# Collecting tcolorpy<1,>=0.0.5 (from pytablewriter~=1.2->rl_zoo3==2.7.0a0)
#   Downloading tcolorpy-0.1.7-py3-none-any.whl.metadata (6.3 kB)
# Collecting typepy<2,>=1.3.2 (from typepy[datetime]<2,>=1.3.2->pytablewriter~=1.2->rl_zoo3==2.7.0a0)
#   Downloading typepy-1.3.4-py3-none-any.whl.metadata (9.2 kB)
# Collecting stable_baselines3<3.0,>=2.7.0a0 (from sb3_contrib<3.0,>=2.7.0a0->rl_zoo3==2.7.0a0)
#   Downloading stable_baselines3-2.7.0a1-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->rl_zoo3==2.7.0a0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->rl_zoo3==2.7.0a0) (2.19.2)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna>=3.0->rl_zoo3==2.7.0a0) (1.1.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.7.0a0) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.7.0a0) (2025.7.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.7.0a0) (2.32.3)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.7.0a0) (1.1.5)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->rl_zoo3==2.7.0a0) (0.1.2)
# Requirement already satisfied: chardet<6,>=3.0.4 in /usr/local/lib/python3.11/dist-packages (from mbstrdecoder<2,>=1.0.0->pytablewriter~=1.2->rl_zoo3==2.7.0a0) (5.2.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna>=3.0->rl_zoo3==2.7.0a0) (3.2.3)
# Requirement already satisfied: torch<3.0,>=2.3 in /usr/local/lib/python3.11/dist-packages (from stable_baselines3<3.0,>=2.7.0a0->sb3_contrib<3.0,>=2.7.0a0->rl_zoo3==2.7.0a0) (2.6.0+cu124)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from stable_baselines3<3.0,>=2.7.0a0->sb3_contrib<3.0,>=2.7.0a0->rl_zoo3==2.7.0a0) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from stable_baselines3<3.0,>=2.7.0a0->sb3_contrib<3.0,>=2.7.0a0->rl_zoo3==2.7.0a0) (3.10.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.0 in /usr/local/lib/python3.11/dist-packages (from typepy[datetime]<2,>=1.3.2->pytablewriter~=1.2->rl_zoo3==2.7.0a0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2018.9 in /usr/local/lib/python3.11/dist-packages (from typepy[datetime]<2,>=1.3.2->pytablewriter~=1.2->rl_zoo3==2.7.0a0) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil<3.0.0,>=2.8.0->typepy[datetime]<2,>=1.3.2->pytablewriter~=1.2->rl_zoo3==2.7.0a0) (1.17.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0a0->sb3_contrib<3.0,>=2.7.0a0->rl_zoo3==2.7.0a0) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0a0->sb3_contrib<3.0,>=2.7.0a0->rl_zoo3==2.7.0a0) (3.1.6)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0a0->sb3_contrib<3.0,>=2.7.0a0->rl_zoo3==2.7.0a0)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0a0->sb3_contrib<3.0,>=2.7.0a0->rl_zoo3==2.7.0a0)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0a0->sb3_contrib<3.0,>=2.7.0a0->rl_zoo3==2.7.0a0)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0a0->sb3_contrib<3.0,>=2.7.0a0->rl_zoo3==2.7.0a0)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0a0->sb3_contrib<3.0,>=2.7.0a0->rl_zoo3==2.7.0a0)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0a0->sb3_contrib<3.0,>=2.7.0a0->rl_zoo3==2.7.0a0)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0a0->sb3_contrib<3.0,>=2.7.0a0->rl_zoo3==2.7.0a0)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0a0->sb3_contrib<3.0,>=2.7.0a0->rl_zoo3==2.7.0a0)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0a0->sb3_contrib<3.0,>=2.7.0a0->rl_zoo3==2.7.0a0)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0a0->sb3_contrib<3.0,>=2.7.0a0->rl_zoo3==2.7.0a0) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0a0->sb3_contrib<3.0,>=2.7.0a0->rl_zoo3==2.7.0a0) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0a0->sb3_contrib<3.0,>=2.7.0a0->rl_zoo3==2.7.0a0) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0a0->sb3_contrib<3.0,>=2.7.0a0->rl_zoo3==2.7.0a0)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0a0->sb3_contrib<3.0,>=2.7.0a0->rl_zoo3==2.7.0a0) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0a0->sb3_contrib<3.0,>=2.7.0a0->rl_zoo3==2.7.0a0) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0a0->sb3_contrib<3.0,>=2.7.0a0->rl_zoo3==2.7.0a0) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3<3.0,>=2.7.0a0->sb3_contrib<3.0,>=2.7.0a0->rl_zoo3==2.7.0a0) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3<3.0,>=2.7.0a0->sb3_contrib<3.0,>=2.7.0a0->rl_zoo3==2.7.0a0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3<3.0,>=2.7.0a0->sb3_contrib<3.0,>=2.7.0a0->rl_zoo3==2.7.0a0) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3<3.0,>=2.7.0a0->sb3_contrib<3.0,>=2.7.0a0->rl_zoo3==2.7.0a0) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3<3.0,>=2.7.0a0->sb3_contrib<3.0,>=2.7.0a0->rl_zoo3==2.7.0a0) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3<3.0,>=2.7.0a0->sb3_contrib<3.0,>=2.7.0a0->rl_zoo3==2.7.0a0) (3.2.3)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->stable_baselines3<3.0,>=2.7.0a0->sb3_contrib<3.0,>=2.7.0a0->rl_zoo3==2.7.0a0) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.7.0a0) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.7.0a0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.7.0a0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3<4.0,>=3.0->rl_zoo3==2.7.0a0) (2025.7.14)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0a0->sb3_contrib<3.0,>=2.7.0a0->rl_zoo3==2.7.0a0) (3.0.2)
# Downloading gymnasium-1.1.1-py3-none-any.whl (965 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 965.4/965.4 kB 20.9 MB/s eta 0:00:00
# Downloading huggingface_sb3-3.0-py3-none-any.whl (9.7 kB)
# Downloading optuna-4.4.0-py3-none-any.whl (395 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 395.9/395.9 kB 35.4 MB/s eta 0:00:00
# Downloading pytablewriter-1.2.1-py3-none-any.whl (91 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.1/91.1 kB 9.3 MB/s eta 0:00:00
# Downloading sb3_contrib-2.7.0a0-py3-none-any.whl (93 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.2/93.2 kB 10.2 MB/s eta 0:00:00
# Downloading Shimmy-2.0.0-py3-none-any.whl (30 kB)
# Downloading alembic-1.16.4-py3-none-any.whl (247 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.0/247.0 kB 24.9 MB/s eta 0:00:00
# Downloading DataProperty-1.1.0-py3-none-any.whl (27 kB)
# Downloading mbstrdecoder-1.1.4-py3-none-any.whl (7.9 kB)
# Downloading pathvalidate-3.3.1-py3-none-any.whl (24 kB)
# Downloading stable_baselines3-2.7.0a1-py3-none-any.whl (187 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 187.2/187.2 kB 20.4 MB/s eta 0:00:00
# Downloading tabledata-1.3.4-py3-none-any.whl (11 kB)
# Downloading tcolorpy-0.1.7-py3-none-any.whl (8.1 kB)
# Downloading typepy-1.3.4-py3-none-any.whl (31 kB)
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 111.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 74.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 61.8 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.1 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.4 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.7 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 96.4 MB/s eta 0:00:00
# Building wheels for collected packages: rl_zoo3
#   Building wheel for rl_zoo3 (pyproject.toml) ... done
#   Created wheel for rl_zoo3: filename=rl_zoo3-2.7.0a0-py3-none-any.whl size=78053 sha256=366da3681f5368fa829741108e4a5abf1766dca8f85b113a856d8b9696823487
#   Stored in directory: /tmp/pip-ephem-wheel-cache-vv0n4y9p/wheels/79/a7/a1/afc7c6c739a99c02b2cba585d219d453a80ab2bff20fb6526f
# Successfully built rl_zoo3
# Installing collected packages: tcolorpy, pathvalidate, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, mbstrdecoder, gymnasium, colorlog, typepy, shimmy, nvidia-cusparse-cu12, nvidia-cudnn-cu12, alembic, optuna, nvidia-cusolver-cu12, huggingface_sb3, DataProperty, tabledata, stable_baselines3, sb3_contrib, pytablewriter, rl_zoo3
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: gymnasium
#     Found existing installation: gymnasium 1.2.0
#     Uninstalling gymnasium-1.2.0:
#       Successfully uninstalled gymnasium-1.2.0
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed DataProperty-1.1.0 alembic-1.16.4 colorlog-6.9.0 gymnasium-1.1.1 huggingface_sb3-3.0 mbstrdecoder-1.1.4 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 optuna-4.4.0 pathvalidate-3.3.1 pytablewriter-1.2.1 rl_zoo3-2.7.0a0 sb3_contrib-2.7.0a0 shimmy-2.0.0 stable_baselines3-2.7.0a1 tabledata-1.3.4 tcolorpy-0.1.7 typepy-1.3.4

# %%
# !apt-get install swig cmake ffmpeg
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# cmake is already the newest version (3.22.1-1ubuntu1.22.04.2).
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# The following additional packages will be installed:
#   swig4.0
# Suggested packages:
#   swig-doc swig-examples swig4.0-examples swig4.0-doc
# The following NEW packages will be installed:
#   swig swig4.0
# 0 upgraded, 2 newly installed, 0 to remove and 35 not upgraded.
# Need to get 1,116 kB of archives.
# After this operation, 5,542 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 swig4.0 amd64 4.0.2-1ubuntu1 [1,110 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 swig all 4.0.2-1ubuntu1 [5,632 B]
# Fetched 1,116 kB in 1s (1,310 kB/s)
# Selecting previously unselected package swig4.0.
# (Reading database ... 126284 files and directories currently installed.)
# Preparing to unpack .../swig4.0_4.0.2-1ubuntu1_amd64.deb ...
# Unpacking swig4.0 (4.0.2-1ubuntu1) ...
# Selecting previously unselected package swig.
# Preparing to unpack .../swig_4.0.2-1ubuntu1_all.deb ...
# Unpacking swig (4.0.2-1ubuntu1) ...
# Setting up swig4.0 (4.0.2-1ubuntu1) ...
# Setting up swig (4.0.2-1ubuntu1) ...
# Processing triggers for man-db (2.10.2-1) ...

# %%
# !pip install gymnasium[atari]
# !pip install gymnasium[accept-rom-license]
# Out:
# Requirement already satisfied: gymnasium[atari] in /usr/local/lib/python3.11/dist-packages (1.1.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[atari]) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[atari]) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[atari]) (4.14.1)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium[atari]) (0.0.4)
# Requirement already satisfied: ale_py>=0.9 in /usr/local/lib/python3.11/dist-packages (from gymnasium[atari]) (0.11.2)
# Requirement already satisfied: gymnasium[accept-rom-license] in /usr/local/lib/python3.11/dist-packages (1.1.1)
# WARNING: gymnasium 1.1.1 does not provide the extra 'accept-rom-license'
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[accept-rom-license]) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[accept-rom-license]) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[accept-rom-license]) (4.14.1)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium[accept-rom-license]) (0.0.4)

# %%
# %%capture
# !apt install python-opengl
# !apt install xvfb
# !pip3 install pyvirtualdisplay

# %%
# Virtual display
from pyvirtualdisplay import Display

virtual_display = Display(visible=0, size=(1400, 900))
virtual_display.start()

# %%
# %%writefile dqn.yml
# SpaceInvadersNoFrameskip-v4:
#   env_wrapper:
#     - stable_baselines3.common.atari_wrappers.AtariWrapper
#   frame_stack: 4
#   policy: 'CnnPolicy'
#   n_timesteps: !!float 1e6
#   buffer_size: 100000
#   learning_rate: !!float 1e-4
#   batch_size: 32
#   learning_starts: 100000
#   target_update_interval: 1000
#   train_freq: 4
#   gradient_steps: 1
#   exploration_fraction: 0.1
#   exploration_final_eps: 0.01
#   optimize_memory_usage: False
# Out:
# Writing dqn.yml

# %%
# !python -m rl_zoo3.train --algo dqn  --env SpaceInvadersNoFrameskip-v4 -f logs/ -c dqn.yml
# Out:
# Streaming output truncated to the last 5000 lines.
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0363   |
# |    n_updates        | 112006   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.95e+03 |
# |    ep_rew_mean      | 371      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2680     |
# |    fps              | 278      |
# |    time_elapsed     | 1969     |
# |    total_timesteps  | 549086   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0342   |
# |    n_updates        | 112271   |
# ----------------------------------
# Eval num_timesteps=550000, episode_reward=368.00 +/- 37.63
# Episode length: 2809.80 +/- 253.16
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 2.81e+03 |
# |    mean_reward      | 368      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 550000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00907  |
# |    n_updates        | 112499   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.94e+03 |
# |    ep_rew_mean      | 369      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2684     |
# |    fps              | 277      |
# |    time_elapsed     | 1982     |
# |    total_timesteps  | 550433   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0372   |
# |    n_updates        | 112608   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.94e+03 |
# |    ep_rew_mean      | 368      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2688     |
# |    fps              | 277      |
# |    time_elapsed     | 1985     |
# |    total_timesteps  | 551347   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0362   |
# |    n_updates        | 112836   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.94e+03 |
# |    ep_rew_mean      | 369      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2692     |
# |    fps              | 277      |
# |    time_elapsed     | 1988     |
# |    total_timesteps  | 552009   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0467   |
# |    n_updates        | 113002   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.94e+03 |
# |    ep_rew_mean      | 370      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2696     |
# |    fps              | 277      |
# |    time_elapsed     | 1992     |
# |    total_timesteps  | 552969   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0719   |
# |    n_updates        | 113242   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.94e+03 |
# |    ep_rew_mean      | 370      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2700     |
# |    fps              | 277      |
# |    time_elapsed     | 1995     |
# |    total_timesteps  | 553824   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0301   |
# |    n_updates        | 113455   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.93e+03 |
# |    ep_rew_mean      | 369      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2704     |
# |    fps              | 277      |
# |    time_elapsed     | 1997     |
# |    total_timesteps  | 554555   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0282   |
# |    n_updates        | 113638   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.94e+03 |
# |    ep_rew_mean      | 370      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2708     |
# |    fps              | 277      |
# |    time_elapsed     | 2003     |
# |    total_timesteps  | 555929   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0342   |
# |    n_updates        | 113982   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.93e+03 |
# |    ep_rew_mean      | 367      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2712     |
# |    fps              | 277      |
# |    time_elapsed     | 2005     |
# |    total_timesteps  | 556747   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0106   |
# |    n_updates        | 114186   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.93e+03 |
# |    ep_rew_mean      | 365      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2716     |
# |    fps              | 277      |
# |    time_elapsed     | 2009     |
# |    total_timesteps  | 557791   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0269   |
# |    n_updates        | 114447   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.93e+03 |
# |    ep_rew_mean      | 364      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2720     |
# |    fps              | 277      |
# |    time_elapsed     | 2012     |
# |    total_timesteps  | 558622   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0233   |
# |    n_updates        | 114655   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.94e+03 |
# |    ep_rew_mean      | 364      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2724     |
# |    fps              | 277      |
# |    time_elapsed     | 2017     |
# |    total_timesteps  | 559821   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.031    |
# |    n_updates        | 114955   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.93e+03 |
# |    ep_rew_mean      | 360      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2728     |
# |    fps              | 277      |
# |    time_elapsed     | 2020     |
# |    total_timesteps  | 560571   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0857   |
# |    n_updates        | 115142   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.93e+03 |
# |    ep_rew_mean      | 359      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2732     |
# |    fps              | 277      |
# |    time_elapsed     | 2022     |
# |    total_timesteps  | 561339   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0248   |
# |    n_updates        | 115334   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.94e+03 |
# |    ep_rew_mean      | 362      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2736     |
# |    fps              | 277      |
# |    time_elapsed     | 2027     |
# |    total_timesteps  | 562417   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0177   |
# |    n_updates        | 115604   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.96e+03 |
# |    ep_rew_mean      | 366      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2740     |
# |    fps              | 277      |
# |    time_elapsed     | 2031     |
# |    total_timesteps  | 563559   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0169   |
# |    n_updates        | 115889   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.98e+03 |
# |    ep_rew_mean      | 369      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2744     |
# |    fps              | 277      |
# |    time_elapsed     | 2035     |
# |    total_timesteps  | 564832   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0331   |
# |    n_updates        | 116207   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.99e+03 |
# |    ep_rew_mean      | 373      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2748     |
# |    fps              | 277      |
# |    time_elapsed     | 2039     |
# |    total_timesteps  | 565827   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0122   |
# |    n_updates        | 116456   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.98e+03 |
# |    ep_rew_mean      | 373      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2752     |
# |    fps              | 277      |
# |    time_elapsed     | 2042     |
# |    total_timesteps  | 566505   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0153   |
# |    n_updates        | 116626   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.97e+03 |
# |    ep_rew_mean      | 374      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2756     |
# |    fps              | 277      |
# |    time_elapsed     | 2045     |
# |    total_timesteps  | 567432   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0634   |
# |    n_updates        | 116857   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.99e+03 |
# |    ep_rew_mean      | 376      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2760     |
# |    fps              | 277      |
# |    time_elapsed     | 2050     |
# |    total_timesteps  | 568613   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0286   |
# |    n_updates        | 117153   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.02e+03 |
# |    ep_rew_mean      | 383      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2764     |
# |    fps              | 277      |
# |    time_elapsed     | 2055     |
# |    total_timesteps  | 569962   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0456   |
# |    n_updates        | 117490   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.01e+03 |
# |    ep_rew_mean      | 381      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2768     |
# |    fps              | 277      |
# |    time_elapsed     | 2060     |
# |    total_timesteps  | 571416   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0106   |
# |    n_updates        | 117853   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3e+03    |
# |    ep_rew_mean      | 383      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2772     |
# |    fps              | 277      |
# |    time_elapsed     | 2064     |
# |    total_timesteps  | 572291   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0277   |
# |    n_updates        | 118072   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3e+03    |
# |    ep_rew_mean      | 384      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2776     |
# |    fps              | 277      |
# |    time_elapsed     | 2069     |
# |    total_timesteps  | 573909   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.026    |
# |    n_updates        | 118477   |
# ----------------------------------
# Eval num_timesteps=575000, episode_reward=491.00 +/- 89.07
# Episode length: 3369.60 +/- 326.98
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 3.37e+03 |
# |    mean_reward      | 491      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 575000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0242   |
# |    n_updates        | 118749   |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.02e+03 |
# |    ep_rew_mean      | 387      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2780     |
# |    fps              | 276      |
# |    time_elapsed     | 2083     |
# |    total_timesteps  | 575145   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0277   |
# |    n_updates        | 118786   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.03e+03 |
# |    ep_rew_mean      | 391      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2784     |
# |    fps              | 275      |
# |    time_elapsed     | 2086     |
# |    total_timesteps  | 575748   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0181   |
# |    n_updates        | 118936   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.02e+03 |
# |    ep_rew_mean      | 388      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2788     |
# |    fps              | 275      |
# |    time_elapsed     | 2088     |
# |    total_timesteps  | 576288   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0165   |
# |    n_updates        | 119071   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.02e+03 |
# |    ep_rew_mean      | 388      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2792     |
# |    fps              | 275      |
# |    time_elapsed     | 2093     |
# |    total_timesteps  | 577608   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0597   |
# |    n_updates        | 119401   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.03e+03 |
# |    ep_rew_mean      | 389      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2796     |
# |    fps              | 275      |
# |    time_elapsed     | 2095     |
# |    total_timesteps  | 578415   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0176   |
# |    n_updates        | 119603   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.05e+03 |
# |    ep_rew_mean      | 396      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2800     |
# |    fps              | 275      |
# |    time_elapsed     | 2101     |
# |    total_timesteps  | 579838   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0784   |
# |    n_updates        | 119959   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.06e+03 |
# |    ep_rew_mean      | 402      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2804     |
# |    fps              | 275      |
# |    time_elapsed     | 2105     |
# |    total_timesteps  | 580961   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0227   |
# |    n_updates        | 120240   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.06e+03 |
# |    ep_rew_mean      | 403      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2808     |
# |    fps              | 275      |
# |    time_elapsed     | 2108     |
# |    total_timesteps  | 581856   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0136   |
# |    n_updates        | 120463   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.08e+03 |
# |    ep_rew_mean      | 408      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2812     |
# |    fps              | 275      |
# |    time_elapsed     | 2113     |
# |    total_timesteps  | 583180   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0203   |
# |    n_updates        | 120794   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.06e+03 |
# |    ep_rew_mean      | 405      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2816     |
# |    fps              | 275      |
# |    time_elapsed     | 2115     |
# |    total_timesteps  | 583795   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.025    |
# |    n_updates        | 120948   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.08e+03 |
# |    ep_rew_mean      | 406      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2820     |
# |    fps              | 275      |
# |    time_elapsed     | 2119     |
# |    total_timesteps  | 584859   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0389   |
# |    n_updates        | 121214   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.06e+03 |
# |    ep_rew_mean      | 404      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2824     |
# |    fps              | 275      |
# |    time_elapsed     | 2123     |
# |    total_timesteps  | 585935   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0254   |
# |    n_updates        | 121483   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.06e+03 |
# |    ep_rew_mean      | 404      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2828     |
# |    fps              | 275      |
# |    time_elapsed     | 2130     |
# |    total_timesteps  | 587902   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0424   |
# |    n_updates        | 121975   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.08e+03 |
# |    ep_rew_mean      | 410      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2832     |
# |    fps              | 275      |
# |    time_elapsed     | 2133     |
# |    total_timesteps  | 588703   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0341   |
# |    n_updates        | 122175   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.08e+03 |
# |    ep_rew_mean      | 410      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2836     |
# |    fps              | 275      |
# |    time_elapsed     | 2138     |
# |    total_timesteps  | 589976   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0401   |
# |    n_updates        | 122493   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.1e+03  |
# |    ep_rew_mean      | 412      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2840     |
# |    fps              | 275      |
# |    time_elapsed     | 2144     |
# |    total_timesteps  | 591684   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0687   |
# |    n_updates        | 122920   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.11e+03 |
# |    ep_rew_mean      | 415      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2844     |
# |    fps              | 275      |
# |    time_elapsed     | 2149     |
# |    total_timesteps  | 592891   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.025    |
# |    n_updates        | 123222   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.08e+03 |
# |    ep_rew_mean      | 410      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2848     |
# |    fps              | 275      |
# |    time_elapsed     | 2151     |
# |    total_timesteps  | 593473   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0289   |
# |    n_updates        | 123368   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.08e+03 |
# |    ep_rew_mean      | 410      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2852     |
# |    fps              | 275      |
# |    time_elapsed     | 2153     |
# |    total_timesteps  | 594169   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0158   |
# |    n_updates        | 123542   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.07e+03 |
# |    ep_rew_mean      | 408      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2856     |
# |    fps              | 275      |
# |    time_elapsed     | 2157     |
# |    total_timesteps  | 595259   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00882  |
# |    n_updates        | 123814   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.08e+03 |
# |    ep_rew_mean      | 411      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2860     |
# |    fps              | 275      |
# |    time_elapsed     | 2162     |
# |    total_timesteps  | 596476   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0224   |
# |    n_updates        | 124118   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.08e+03 |
# |    ep_rew_mean      | 410      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2864     |
# |    fps              | 275      |
# |    time_elapsed     | 2165     |
# |    total_timesteps  | 597449   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0228   |
# |    n_updates        | 124362   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.09e+03 |
# |    ep_rew_mean      | 410      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2868     |
# |    fps              | 275      |
# |    time_elapsed     | 2168     |
# |    total_timesteps  | 598272   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0593   |
# |    n_updates        | 124567   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.09e+03 |
# |    ep_rew_mean      | 412      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2872     |
# |    fps              | 275      |
# |    time_elapsed     | 2175     |
# |    total_timesteps  | 599882   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0534   |
# |    n_updates        | 124970   |
# ----------------------------------
# Eval num_timesteps=600000, episode_reward=490.00 +/- 106.77
# Episode length: 3665.60 +/- 493.98
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 3.67e+03 |
# |    mean_reward      | 490      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 600000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0287   |
# |    n_updates        | 124999   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.11e+03 |
# |    ep_rew_mean      | 415      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2876     |
# |    fps              | 274      |
# |    time_elapsed     | 2188     |
# |    total_timesteps  | 600918   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.027    |
# |    n_updates        | 125229   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.14e+03 |
# |    ep_rew_mean      | 418      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2880     |
# |    fps              | 274      |
# |    time_elapsed     | 2193     |
# |    total_timesteps  | 602273   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0199   |
# |    n_updates        | 125568   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.14e+03 |
# |    ep_rew_mean      | 419      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2884     |
# |    fps              | 274      |
# |    time_elapsed     | 2199     |
# |    total_timesteps  | 603707   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.017    |
# |    n_updates        | 125926   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.17e+03 |
# |    ep_rew_mean      | 428      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2888     |
# |    fps              | 274      |
# |    time_elapsed     | 2204     |
# |    total_timesteps  | 605163   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0759   |
# |    n_updates        | 126290   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.16e+03 |
# |    ep_rew_mean      | 427      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2892     |
# |    fps              | 274      |
# |    time_elapsed     | 2208     |
# |    total_timesteps  | 606333   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0131   |
# |    n_updates        | 126583   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.18e+03 |
# |    ep_rew_mean      | 429      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2896     |
# |    fps              | 274      |
# |    time_elapsed     | 2213     |
# |    total_timesteps  | 607590   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0177   |
# |    n_updates        | 126897   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.18e+03 |
# |    ep_rew_mean      | 430      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2900     |
# |    fps              | 274      |
# |    time_elapsed     | 2218     |
# |    total_timesteps  | 609114   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0417   |
# |    n_updates        | 127278   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.19e+03 |
# |    ep_rew_mean      | 432      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2904     |
# |    fps              | 274      |
# |    time_elapsed     | 2224     |
# |    total_timesteps  | 610487   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0194   |
# |    n_updates        | 127621   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.19e+03 |
# |    ep_rew_mean      | 431      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2908     |
# |    fps              | 274      |
# |    time_elapsed     | 2228     |
# |    total_timesteps  | 611591   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0175   |
# |    n_updates        | 127897   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.21e+03 |
# |    ep_rew_mean      | 435      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2912     |
# |    fps              | 274      |
# |    time_elapsed     | 2234     |
# |    total_timesteps  | 613207   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0548   |
# |    n_updates        | 128301   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.23e+03 |
# |    ep_rew_mean      | 442      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2916     |
# |    fps              | 274      |
# |    time_elapsed     | 2240     |
# |    total_timesteps  | 614706   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0657   |
# |    n_updates        | 128676   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.25e+03 |
# |    ep_rew_mean      | 442      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2920     |
# |    fps              | 274      |
# |    time_elapsed     | 2243     |
# |    total_timesteps  | 615534   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0617   |
# |    n_updates        | 128883   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.25e+03 |
# |    ep_rew_mean      | 445      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2924     |
# |    fps              | 274      |
# |    time_elapsed     | 2247     |
# |    total_timesteps  | 616647   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0243   |
# |    n_updates        | 129161   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.26e+03 |
# |    ep_rew_mean      | 448      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2928     |
# |    fps              | 274      |
# |    time_elapsed     | 2250     |
# |    total_timesteps  | 617562   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0691   |
# |    n_updates        | 129390   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.28e+03 |
# |    ep_rew_mean      | 453      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2932     |
# |    fps              | 274      |
# |    time_elapsed     | 2257     |
# |    total_timesteps  | 619448   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.012    |
# |    n_updates        | 129861   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.27e+03 |
# |    ep_rew_mean      | 452      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2936     |
# |    fps              | 274      |
# |    time_elapsed     | 2260     |
# |    total_timesteps  | 620198   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0184   |
# |    n_updates        | 130049   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.28e+03 |
# |    ep_rew_mean      | 452      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2940     |
# |    fps              | 274      |
# |    time_elapsed     | 2266     |
# |    total_timesteps  | 621801   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0155   |
# |    n_updates        | 130450   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.3e+03  |
# |    ep_rew_mean      | 456      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2944     |
# |    fps              | 274      |
# |    time_elapsed     | 2269     |
# |    total_timesteps  | 622899   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0538   |
# |    n_updates        | 130724   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.29e+03 |
# |    ep_rew_mean      | 453      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2948     |
# |    fps              | 274      |
# |    time_elapsed     | 2273     |
# |    total_timesteps  | 623712   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.019    |
# |    n_updates        | 130927   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.28e+03 |
# |    ep_rew_mean      | 451      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2952     |
# |    fps              | 274      |
# |    time_elapsed     | 2276     |
# |    total_timesteps  | 624454   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0306   |
# |    n_updates        | 131113   |
# ----------------------------------
# Eval num_timesteps=625000, episode_reward=443.00 +/- 126.16
# Episode length: 3372.20 +/- 641.45
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 3.37e+03 |
# |    mean_reward      | 443      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 625000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0107   |
# |    n_updates        | 131249   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.28e+03 |
# |    ep_rew_mean      | 452      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2956     |
# |    fps              | 273      |
# |    time_elapsed     | 2289     |
# |    total_timesteps  | 625480   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0356   |
# |    n_updates        | 131369   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.3e+03  |
# |    ep_rew_mean      | 453      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2960     |
# |    fps              | 273      |
# |    time_elapsed     | 2294     |
# |    total_timesteps  | 626949   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0199   |
# |    n_updates        | 131737   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.28e+03 |
# |    ep_rew_mean      | 451      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2964     |
# |    fps              | 273      |
# |    time_elapsed     | 2298     |
# |    total_timesteps  | 627965   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.014    |
# |    n_updates        | 131991   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.27e+03 |
# |    ep_rew_mean      | 446      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2968     |
# |    fps              | 273      |
# |    time_elapsed     | 2302     |
# |    total_timesteps  | 629082   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0345   |
# |    n_updates        | 132270   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.27e+03 |
# |    ep_rew_mean      | 443      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2972     |
# |    fps              | 273      |
# |    time_elapsed     | 2307     |
# |    total_timesteps  | 630511   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0767   |
# |    n_updates        | 132627   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.27e+03 |
# |    ep_rew_mean      | 442      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2976     |
# |    fps              | 273      |
# |    time_elapsed     | 2314     |
# |    total_timesteps  | 632267   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0277   |
# |    n_updates        | 133066   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.32e+03 |
# |    ep_rew_mean      | 449      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2980     |
# |    fps              | 273      |
# |    time_elapsed     | 2317     |
# |    total_timesteps  | 633240   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0118   |
# |    n_updates        | 133309   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.32e+03 |
# |    ep_rew_mean      | 449      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2984     |
# |    fps              | 273      |
# |    time_elapsed     | 2321     |
# |    total_timesteps  | 634176   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0559   |
# |    n_updates        | 133543   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.33e+03 |
# |    ep_rew_mean      | 451      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2988     |
# |    fps              | 273      |
# |    time_elapsed     | 2326     |
# |    total_timesteps  | 635594   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0274   |
# |    n_updates        | 133898   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.34e+03 |
# |    ep_rew_mean      | 453      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2992     |
# |    fps              | 273      |
# |    time_elapsed     | 2329     |
# |    total_timesteps  | 636324   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0242   |
# |    n_updates        | 134080   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.34e+03 |
# |    ep_rew_mean      | 455      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2996     |
# |    fps              | 273      |
# |    time_elapsed     | 2333     |
# |    total_timesteps  | 637353   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0342   |
# |    n_updates        | 134338   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.34e+03 |
# |    ep_rew_mean      | 454      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3000     |
# |    fps              | 273      |
# |    time_elapsed     | 2339     |
# |    total_timesteps  | 638942   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0354   |
# |    n_updates        | 134735   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.38e+03 |
# |    ep_rew_mean      | 459      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3004     |
# |    fps              | 273      |
# |    time_elapsed     | 2348     |
# |    total_timesteps  | 641550   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0331   |
# |    n_updates        | 135387   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.4e+03  |
# |    ep_rew_mean      | 463      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3008     |
# |    fps              | 273      |
# |    time_elapsed     | 2351     |
# |    total_timesteps  | 642231   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00826  |
# |    n_updates        | 135557   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.39e+03 |
# |    ep_rew_mean      | 463      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3012     |
# |    fps              | 273      |
# |    time_elapsed     | 2353     |
# |    total_timesteps  | 642888   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0191   |
# |    n_updates        | 135721   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.4e+03  |
# |    ep_rew_mean      | 465      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3016     |
# |    fps              | 273      |
# |    time_elapsed     | 2359     |
# |    total_timesteps  | 644375   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0112   |
# |    n_updates        | 136093   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.41e+03 |
# |    ep_rew_mean      | 466      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3020     |
# |    fps              | 273      |
# |    time_elapsed     | 2363     |
# |    total_timesteps  | 645476   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0166   |
# |    n_updates        | 136368   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.44e+03 |
# |    ep_rew_mean      | 471      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3024     |
# |    fps              | 273      |
# |    time_elapsed     | 2368     |
# |    total_timesteps  | 646895   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# ...
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0362   |
# |    n_updates        | 212598   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.82e+03 |
# |    ep_rew_mean      | 575      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3824     |
# |    fps              | 263      |
# |    time_elapsed     | 3618     |
# |    total_timesteps  | 951777   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0113   |
# |    n_updates        | 212944   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.88e+03 |
# |    ep_rew_mean      | 586      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3828     |
# |    fps              | 263      |
# |    time_elapsed     | 3625     |
# |    total_timesteps  | 953982   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0109   |
# |    n_updates        | 213495   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.87e+03 |
# |    ep_rew_mean      | 585      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3832     |
# |    fps              | 263      |
# |    time_elapsed     | 3632     |
# |    total_timesteps  | 955800   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0341   |
# |    n_updates        | 213949   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.87e+03 |
# |    ep_rew_mean      | 586      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3836     |
# |    fps              | 263      |
# |    time_elapsed     | 3637     |
# |    total_timesteps  | 957161   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0157   |
# |    n_updates        | 214290   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.87e+03 |
# |    ep_rew_mean      | 583      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3840     |
# |    fps              | 263      |
# |    time_elapsed     | 3641     |
# |    total_timesteps  | 958244   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0121   |
# |    n_updates        | 214560   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.88e+03 |
# |    ep_rew_mean      | 585      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3844     |
# |    fps              | 263      |
# |    time_elapsed     | 3648     |
# |    total_timesteps  | 960159   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0106   |
# |    n_updates        | 215039   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.88e+03 |
# |    ep_rew_mean      | 580      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3848     |
# |    fps              | 263      |
# |    time_elapsed     | 3654     |
# |    total_timesteps  | 961788   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0375   |
# |    n_updates        | 215446   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.89e+03 |
# |    ep_rew_mean      | 587      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3852     |
# |    fps              | 263      |
# |    time_elapsed     | 3660     |
# |    total_timesteps  | 963458   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0258   |
# |    n_updates        | 215864   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.89e+03 |
# |    ep_rew_mean      | 585      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3856     |
# |    fps              | 263      |
# |    time_elapsed     | 3665     |
# |    total_timesteps  | 964934   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0183   |
# |    n_updates        | 216233   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.89e+03 |
# |    ep_rew_mean      | 585      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3860     |
# |    fps              | 263      |
# |    time_elapsed     | 3670     |
# |    total_timesteps  | 966261   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.021    |
# |    n_updates        | 216565   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.88e+03 |
# |    ep_rew_mean      | 585      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3864     |
# |    fps              | 263      |
# |    time_elapsed     | 3676     |
# |    total_timesteps  | 967967   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0339   |
# |    n_updates        | 216991   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.87e+03 |
# |    ep_rew_mean      | 584      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3868     |
# |    fps              | 263      |
# |    time_elapsed     | 3681     |
# |    total_timesteps  | 969456   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0313   |
# |    n_updates        | 217363   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.87e+03 |
# |    ep_rew_mean      | 587      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3872     |
# |    fps              | 263      |
# |    time_elapsed     | 3685     |
# |    total_timesteps  | 970567   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0108   |
# |    n_updates        | 217641   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.87e+03 |
# |    ep_rew_mean      | 587      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3876     |
# |    fps              | 263      |
# |    time_elapsed     | 3694     |
# |    total_timesteps  | 973047   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0115   |
# |    n_updates        | 218261   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.88e+03 |
# |    ep_rew_mean      | 587      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3880     |
# |    fps              | 263      |
# |    time_elapsed     | 3701     |
# |    total_timesteps  | 974866   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0229   |
# |    n_updates        | 218716   |
# ----------------------------------
# Eval num_timesteps=975000, episode_reward=554.00 +/- 171.51
# Episode length: 3985.20 +/- 671.08
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 3.99e+03 |
# |    mean_reward      | 554      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 975000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0165   |
# |    n_updates        | 218749   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.89e+03 |
# |    ep_rew_mean      | 592      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3884     |
# |    fps              | 262      |
# |    time_elapsed     | 3721     |
# |    total_timesteps  | 977620   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0307   |
# |    n_updates        | 219404   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.88e+03 |
# |    ep_rew_mean      | 590      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3888     |
# |    fps              | 262      |
# |    time_elapsed     | 3728     |
# |    total_timesteps  | 979622   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0195   |
# |    n_updates        | 219905   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.86e+03 |
# |    ep_rew_mean      | 584      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3892     |
# |    fps              | 262      |
# |    time_elapsed     | 3731     |
# |    total_timesteps  | 980457   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0136   |
# |    n_updates        | 220114   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.86e+03 |
# |    ep_rew_mean      | 584      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3896     |
# |    fps              | 262      |
# |    time_elapsed     | 3738     |
# |    total_timesteps  | 982422   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0229   |
# |    n_updates        | 220605   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.86e+03 |
# |    ep_rew_mean      | 579      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3900     |
# |    fps              | 262      |
# |    time_elapsed     | 3742     |
# |    total_timesteps  | 983619   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0128   |
# |    n_updates        | 220904   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.86e+03 |
# |    ep_rew_mean      | 580      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3904     |
# |    fps              | 262      |
# |    time_elapsed     | 3751     |
# |    total_timesteps  | 986027   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0227   |
# |    n_updates        | 221506   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.88e+03 |
# |    ep_rew_mean      | 584      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3908     |
# |    fps              | 262      |
# |    time_elapsed     | 3756     |
# |    total_timesteps  | 987383   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.035    |
# |    n_updates        | 221845   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.88e+03 |
# |    ep_rew_mean      | 586      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3912     |
# |    fps              | 262      |
# |    time_elapsed     | 3764     |
# |    total_timesteps  | 989596   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.021    |
# |    n_updates        | 222398   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.88e+03 |
# |    ep_rew_mean      | 591      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3916     |
# |    fps              | 262      |
# |    time_elapsed     | 3771     |
# |    total_timesteps  | 991585   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0189   |
# |    n_updates        | 222896   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.88e+03 |
# |    ep_rew_mean      | 590      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3920     |
# |    fps              | 262      |
# |    time_elapsed     | 3778     |
# |    total_timesteps  | 993609   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00814  |
# |    n_updates        | 223402   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.91e+03 |
# |    ep_rew_mean      | 595      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3924     |
# |    fps              | 262      |
# |    time_elapsed     | 3787     |
# |    total_timesteps  | 995939   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0146   |
# |    n_updates        | 223984   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.91e+03 |
# |    ep_rew_mean      | 596      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3928     |
# |    fps              | 263      |
# |    time_elapsed     | 3792     |
# |    total_timesteps  | 997476   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0136   |
# |    n_updates        | 224368   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.92e+03 |
# |    ep_rew_mean      | 597      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3932     |
# |    fps              | 263      |
# |    time_elapsed     | 3797     |
# |    total_timesteps  | 999002   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0107   |
# |    n_updates        | 224750   |
# ----------------------------------
# Eval num_timesteps=1000000, episode_reward=474.00 +/- 64.61
# Episode length: 3032.60 +/- 390.27
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 3.03e+03 |
# |    mean_reward      | 474      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 1000000  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0375   |
# |    n_updates        | 224999   |
# ----------------------------------
# Saving to logs//dqn/SpaceInvadersNoFrameskip-v4_1

# %%
# !python -m rl_zoo3.enjoy  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --no-render  --n-timesteps 5000  --folder logs/
# Out:
# 2025-07-24 02:27:15.488398: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1753324035.508611   21900 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1753324035.515055   21900 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-07-24 02:27:15.536063: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Loading latest experiment, id=1
# Loading logs/dqn/SpaceInvadersNoFrameskip-v4_1/SpaceInvadersNoFrameskip-v4.zip
# A.L.E: Arcade Learning Environment (version 0.11.2+ecc1138)
# [Powered by Stella]
# Stacking 4 frames
# Atari Episode Score: 605.00
# Atari Episode Length 3427
# Atari Episode Score: 605.00
# Atari Episode Length 3241
# Atari Episode Score: 550.00
# Atari Episode Length 4165
# Atari Episode Score: 415.00
# Atari Episode Length 2963
# Atari Episode Score: 490.00
# Atari Episode Length 3555

# %%
from huggingface_hub import notebook_login # To log to our Hugging Face account to be able to upload models to the Hub.
notebook_login()
# !git config --global credential.helper store
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
# !python -m rl_zoo3.push_to_hub  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --repo-name dqn-SpaceInvadersNoFrameskip-v4  -orga rlshiv  -f logs/
# Out:
# 2025-07-24 02:29:15.860301: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1753324155.880748   22419 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1753324155.888420   22419 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-07-24 02:29:15.908615: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Loading latest experiment, id=1
# Loading logs/dqn/SpaceInvadersNoFrameskip-v4_1/SpaceInvadersNoFrameskip-v4.zip
# A.L.E: Arcade Learning Environment (version 0.11.2+ecc1138)
# [Powered by Stella]
# Stacking 4 frames
# Wrapping the env in a VecTransposeImage.
# Uploading to rlshiv/dqn-SpaceInvadersNoFrameskip-v4, make sure to have the rights
# ℹ This function will save, evaluate, generate a video of your agent,
# create a model card and push everything to the hub. It might take up to some
# minutes if video generation is activated. This is a work in progress: if you
# encounter a bug, please open an issue.
# Fetching 1 files:   0% 0/1 [00:00<?, ?it/s]
# .gitattributes: 1.52kB [00:00, 3.49MB/s]
# Fetching 1 files: 100% 1/1 [00:00<00:00,  2.75it/s]
# Saving model to: hub/dqn-SpaceInvadersNoFrameskip-v4/dqn-SpaceInvadersNoFrameskip-v4
# Saving video to /tmp/tmpaklue_8g/-step-0-to-step-1000.mp4
# /usr/local/lib/python3.11/dist-packages/moviepy/config_defaults.py:1: DeprecationWarning: invalid escape sequence '\P'
#   """
# Moviepy - Building video /tmp/tmpaklue_8g/-step-0-to-step-1000.mp4.
# Moviepy - Writing video /tmp/tmpaklue_8g/-step-0-to-step-1000.mp4
#
# Moviepy - Done !
# Moviepy - video ready /tmp/tmpaklue_8g/-step-0-to-step-1000.mp4
# ✘ 'DummyVecEnv' object has no attribute 'video_recorder'
# ✘ We are unable to generate a replay of your agent, the package_to_hub
# process continues
# ✘ Please open an issue at
# https://github.com/huggingface/huggingface_sb3/issues
# ℹ Pushing repo dqn-SpaceInvadersNoFrameskip-v4 to the Hugging Face
# Hub
# Uploading...: 100% 54.3M/54.3M [00:02<00:00, 19.2MB/s]
# ℹ Your model is pushed to the hub. You can view your model here:
# https://huggingface.co/rlshiv/dqn-SpaceInvadersNoFrameskip-v4
